# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from scipy.stats import kruskal
import itertools

# 读取数据
data = pd.read_excel('附件一（训练集）.xlsx')

# 提取特征（第1到第4列）和磁通密度列（第5到第1029列）
leixing = data.iloc[:, 0]
temperature = data.iloc[:, 1]
core_loss = data.iloc[:, 3]
excitation_waveform = data.iloc[:, 4]

# 编码分类变量
label_encoder = LabelEncoder()
excitation_waveform_encoded = label_encoder.fit_transform(excitation_waveform)
leixing_encoded = label_encoder.fit_transform(leixing)

# 构建特征矩阵
features = pd.DataFrame({
    'temperature': temperature,
    'excitation_waveform': excitation_waveform_encoded,
    'leixing': leixing_encoded
})

# 交互作用检验
def interaction_test(var1, var2):
    # 组合自变量
    interaction = features[var1].astype(str) + '_' + features[var2].astype(str)
    features['interaction'] = interaction

    # 准备进行检验
    groups = features.groupby('interaction')[core_loss.name].apply(list)
    stat, p_value = kruskal(*groups)

    return stat, p_value

# 检验不同变量的交互作用
variables = ['leixing', 'excitation_waveform', 'temperature']
results = {}

for var1, var2 in itertools.combinations(variables, 2):
    stat, p_value = interaction_test(var1, var2)
    results[f'{var1} x {var2}'] = {'statistic': stat, 'p-value': p_value}

# 输出结果
for interaction, result in results.items():
    print(f'Interaction: {interaction}, Statistic: {result["statistic"]}, p-value: {result["p-value"]}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 45
#      42 results = {}
#      44 for var1, var2 in itertools.combinations(variables, 2):
# ---> 45     stat, p_value = interaction_test(var1, var2)
#      46     results[f'{var1} x {var2}'] = {'statistic': stat, 'p-value': p_value}
#      48 # 输出结果
#
# Cell In[1], line 35, in interaction_test(var1, var2)
#      32 features['interaction'] = interaction
#      34 # 准备进行检验
# ---> 35 groups = features.groupby('interaction')[core_loss.name].apply(list)
#      36 stat, p_value = kruskal(*groups)
#      38 return stat, p_value
#
# File d:\Anaconda\envs\pytorch\lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File d:\Anaconda\envs\pytorch\lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: 磁芯损耗，w/m3'

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from scipy.stats import kruskal
import itertools

# 读取数据
data = pd.read_excel('附件一（训练集）.xlsx')

# 提取特征（第1到第4列）和磁通密度列（第5到第1029列）
leixing = data.iloc[:, 0]
temperature = data.iloc[:, 1]
core_loss = data.iloc[:, 3]  # 确保这里的索引正确
excitation_waveform = data.iloc[:, 4]

# 编码分类变量
label_encoder = LabelEncoder()
excitation_waveform_encoded = label_encoder.fit_transform(excitation_waveform)
leixing_encoded = label_encoder.fit_transform(leixing)

# 构建特征矩阵
features = pd.DataFrame({
    'temperature': temperature,
    'excitation_waveform': excitation_waveform_encoded,
    'leixing': leixing_encoded,
    'core_loss': core_loss  # 将 core_loss 添加到特征矩阵中
})

# 交互作用检验
def interaction_test(var1, var2):
    # 组合自变量
    interaction = features[var1].astype(str) + '_' + features[var2].astype(str)
    features['interaction'] = interaction

    # 准备进行检验
    groups = features.groupby('interaction')['core_loss'].apply(list)
    stat, p_value = kruskal(*groups)

    return stat, p_value

# 检验不同变量的交互作用
variables = ['leixing', 'excitation_waveform', 'temperature']
results = {}

for var1, var2 in itertools.combinations(variables, 2):
    stat, p_value = interaction_test(var1, var2)
    results[f'{var1} x {var2}'] = {'statistic': stat, 'p-value': p_value}

# 输出结果
for interaction, result in results.items():
    print(f'Interaction: {interaction}, Statistic: {result["statistic"]}, p-value: {result["p-value"]}')
# Out:
# Interaction: leixing x excitation_waveform, Statistic: 1174.2621580753141, p-value: 5.701628975408755e-245
# Interaction: leixing x temperature, Statistic: 363.4425584471862, p-value: 3.2298626487044606e-68
# Interaction: excitation_waveform x temperature, Statistic: 919.9240744401806, p-value: 3.2261009925169954e-190

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from scipy.stats import kruskal
import itertools

# 假设data已经加载为DataFrame
leixing = data.iloc[:, 0].values.reshape(-1, 1)
temperature = data.iloc[:, 1].values.reshape(-1, 1)
core_loss = data.iloc[:, 3].values  # 确保这里的索引正确
excitation_waveform = data.iloc[:, 4].values.reshape(-1, 1)

# 对励磁波形、温度和材料进行独热编码
waveform_encoder = OneHotEncoder(sparse_output=False)
temperature_encoder = OneHotEncoder(sparse_output=False)
leixing_encoder = OneHotEncoder(sparse_output=False)

leixing_encoded = leixing_encoder.fit_transform(leixing)
temperature_encoded = temperature_encoder.fit_transform(temperature)
excitation_waveform_encoded = waveform_encoder.fit_transform(excitation_waveform)

# 将编码结果合并到一个DataFrame中
features = pd.DataFrame(np.hstack([leixing_encoded, temperature_encoded, excitation_waveform_encoded]), 
                        columns=(leixing_encoder.get_feature_names_out().tolist() + 
                                 temperature_encoder.get_feature_names_out().tolist() + 
                                 waveform_encoder.get_feature_names_out().tolist()))

# 添加因变量core_loss
features['core_loss'] = core_loss

# 交互作用检验
def interaction_test(var1, var2):
    # 组合自变量
    interaction = features[var1].astype(str) + '_' + features[var2].astype(str)
    features['interaction'] = interaction

    # 准备进行检验
    groups = features.groupby('interaction')['core_loss'].apply(list)
    stat, p_value = kruskal(*groups)

    return stat, p_value

# 检验不同变量的交互作用
variables = features.columns[:-1]  # 选择自变量，不包括因变量
results = {}

for var1, var2 in itertools.combinations(variables, 2):
    stat, p_value = interaction_test(var1, var2)
    results[f'Interaction {var1} x {var2}'] = {'statistic': stat, 'p-value': p_value}

# 输出结果
for interaction, result in results.items():
    print(f'{interaction}, Statistic: {result["statistic"]}, p-value: {result["p-value"]}')
# Out:
# Interaction x0_材料1 x x0_材料2, Statistic: 34.74415246719091, p-value: 2.853666076713013e-08
# Interaction x0_材料1 x x0_材料3, Statistic: 114.6874727867579, p-value: 1.247187394252569e-25
# Interaction x0_材料1 x x0_材料4, Statistic: 288.77277549674596, p-value: 1.9669283451572606e-63
# Interaction x0_材料1 x x0_25, Statistic: 58.64969324477283, p-value: 1.1420313920047882e-12
# Interaction x0_材料1 x x0_50, Statistic: 1.069891576480967, p-value: 0.7843468924715999
# Interaction x0_材料1 x x0_70, Statistic: 17.020847046067452, p-value: 0.0006997993894159842
# Interaction x0_材料1 x x0_90, Statistic: 18.47839612928546, p-value: 0.000350410565764165
# Interaction x0_材料1 x x0_三角波, Statistic: 282.4110085628947, p-value: 6.369997661637798e-61
# Interaction x0_材料1 x x0_梯形波, Statistic: 164.56268795738916, p-value: 1.898399156085309e-35
# Interaction x0_材料1 x x0_正弦波, Statistic: 824.8241311608167, p-value: 1.7879771500583213e-178
# Interaction x0_材料2 x x0_材料3, Statistic: 200.43259441187928, p-value: 2.9965058278453686e-44
# Interaction x0_材料2 x x0_材料4, Statistic: 248.04732551292062, p-value: 1.3715373516963497e-54
# Interaction x0_材料2 x x0_25, Statistic: 90.26509486924441, p-value: 1.9213986680924495e-19
# Interaction x0_材料2 x x0_50, Statistic: 34.09682056477285, p-value: 1.8901025042492628e-07
# Interaction x0_材料2 x x0_70, Statistic: 49.91877153312318, p-value: 8.313827243768278e-11
# Interaction x0_材料2 x x0_90, Statistic: 50.43529357050889, p-value: 6.453433044578675e-11
# Interaction x0_材料2 x x0_三角波, Statistic: 336.49429918681415, p-value: 1.2528676407498733e-72
# Interaction x0_材料2 x x0_梯形波, Statistic: 169.83925625560693, p-value: 1.378377202510372e-36
# Interaction x0_材料2 x x0_正弦波, Statistic: 875.1557135635235, p-value: 2.1668533751194196e-189
# Interaction x0_材料3 x x0_材料4, Statistic: 277.7920928088029, p-value: 4.766652460293575e-61
# Interaction x0_材料3 x x0_25, Statistic: 161.6339524309429, p-value: 8.137705020355884e-35
# Interaction x0_材料3 x x0_50, Statistic: 105.93394284844955, p-value: 8.226921593892592e-23
# Interaction x0_材料3 x x0_70, Statistic: 120.74906517264965, p-value: 5.32241361042113e-26
# Interaction x0_材料3 x x0_90, Statistic: 123.08534099530374, p-value: 1.6706574239677165e-26
# Interaction x0_材料3 x x0_三角波, Statistic: 410.88941303204996, p-value: 9.690658545081112e-89
# Interaction x0_材料3 x x0_梯形波, Statistic: 235.74540670360898, p-value: 7.916399197215614e-51
# Interaction x0_材料3 x x0_正弦波, Statistic: 923.5484481970711, p-value: 6.904654881074534e-200
# Interaction x0_材料4 x x0_25, Statistic: 302.7043047180066, p-value: 2.5850707812996644e-65
# Interaction x0_材料4 x x0_50, Statistic: 248.37164965482452, p-value: 1.4723489357294838e-53
# Interaction x0_材料4 x x0_70, Statistic: 263.6935930365532, p-value: 7.141531638614114e-57
# Interaction x0_材料4 x x0_90, Statistic: 264.2340639038613, p-value: 5.45595637386758e-57
# Interaction x0_材料4 x x0_三角波, Statistic: 603.3973390553597, p-value: 1.848810297415243e-130
# Interaction x0_材料4 x x0_梯形波, Statistic: 353.30098811924984, p-value: 2.876747623240234e-76
# Interaction x0_材料4 x x0_正弦波, Statistic: 1086.3295129738071, p-value: 3.364058776174946e-235
# Interaction x0_25 x x0_50, Statistic: 67.70186471600853, p-value: 1.98942178637738e-15
# Interaction x0_25 x x0_70, Statistic: 59.469559709110605, p-value: 1.2199701050252758e-13
# Interaction x0_25 x x0_90, Statistic: 59.91542210354661, p-value: 9.761833585464785e-14
# Interaction x0_25 x x0_三角波, Statistic: 335.37547986622286, p-value: 2.188440718280692e-72
# Interaction x0_25 x x0_梯形波, Statistic: 212.8444022801384, p-value: 7.070053724381893e-46
# Interaction x0_25 x x0_正弦波, Statistic: 890.846671300158, p-value: 8.559165970377515e-193
# Interaction x0_50 x x0_70, Statistic: 17.02338758452677, p-value: 0.0002011029097213213
# Interaction x0_50 x x0_90, Statistic: 18.286426735304165, p-value: 0.00010694312919483549
# Interaction x0_50 x x0_三角波, Statistic: 276.76925988435664, p-value: 1.05895758103752e-59
# Interaction x0_50 x x0_梯形波, Statistic: 141.34392897573932, p-value: 1.939434357218952e-30
# Interaction x0_50 x x0_正弦波, Statistic: 819.8842092746713, p-value: 2.107420087040113e-177
# Interaction x0_70 x x0_90, Statistic: 49.941739385782405, p-value: 1.4298454050103336e-11
# Interaction x0_70 x x0_三角波, Statistic: 293.78591338180297, p-value: 2.2010292712453462e-63
# Interaction x0_70 x x0_梯形波, Statistic: 158.84541838560637, p-value: 3.2530577712012785e-34
# Interaction x0_70 x x0_正弦波, Statistic: 843.0252584431062, p-value: 2.017277664118557e-182
# Interaction x0_90 x x0_三角波, Statistic: 294.8331252683335, p-value: 1.306153150924826e-63
# Interaction x0_90 x x0_梯形波, Statistic: 167.45825105870964, p-value: 4.501598463277355e-36
# Interaction x0_90 x x0_正弦波, Statistic: 841.0831393988167, p-value: 5.320982460187265e-182
# Interaction x0_三角波 x x0_梯形波, Statistic: 819.8756854292031, p-value: 9.252455088977447e-179
# Interaction x0_三角波 x x0_正弦波, Statistic: 819.8756854292031, p-value: 9.252455088977447e-179
# Interaction x0_梯形波 x x0_正弦波, Statistic: 819.8756854292031, p-value: 9.252455088977447e-179

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# 假设data已经加载为DataFrame
leixing= data.iloc[:, 0].values  # 材料类型
temperature = data.iloc[:, 1].values  # 温度
core_loss = data.iloc[:, 3].values  # 核损耗
excitation_waveform= data.iloc[:, 4].values  # 励磁波形
# 将你的数据转换为DataFrame，并确保分类变量的正确处理
data = pd.DataFrame({
    'leixing': leixing,  # 材料类型
    'temperature': temperature,  # 温度
    'core_loss': core_loss,  # 核损耗
    'excitation_waveform': excitation_waveform  # 励磁波形
})

# 确保这些列被视为分类变量
data['leixing'] = data['leixing'].astype('category')
data['temperature'] = data['temperature'].astype('category')
data['excitation_waveform'] = data['excitation_waveform'].astype('category')

# 使用包含交互项的线性模型
formula = 'core_loss ~ C(leixing) * C(temperature) * C(excitation_waveform)'
model = smf.ols(formula=formula, data=data).fit()

# 输出模型摘要结果，查看系数和交互项的显著性
print(model.summary())

# 获取交互效应的p值
interaction_pvalues = model.pvalues
print(interaction_pvalues)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              core_loss   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     23.20
# Date:                Sun, 22 Sep 2024   Prob (F-statistic):          1.51e-188
# Time:                        15:19:50   Log-Likelihood:            -1.7626e+05
# No. Observations:               12400   AIC:                         3.526e+05
# Df Residuals:                   12352   BIC:                         3.530e+05
# Df Model:                          47
# Covariance Type:            nonrobust
# ========================================================================================================================================
#                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                             2.787e+05   1.88e+04     14.835      0.000    2.42e+05    3.16e+05
# C(leixing)[T.材料2]                                                     1.368e+05   2.98e+04      4.590      0.000    7.84e+04    1.95e+05
# C(leixing)[T.材料3]                                                     1.085e+05   2.87e+04      3.786      0.000    5.23e+04    1.65e+05
# C(leixing)[T.材料4]                                                    -1.251e+05   2.54e+04     -4.920      0.000   -1.75e+05   -7.53e+04
# C(temperature)[T.50]                                                 -4.382e+04   2.68e+04     -1.634      0.102   -9.64e+04    8743.994
# C(temperature)[T.70]                                                 -8.165e+04   2.71e+04     -3.009      0.003   -1.35e+05   -2.85e+04
# C(temperature)[T.90]                                                 -7.697e+04   2.71e+04     -2.843      0.004    -1.3e+05   -2.39e+04
# C(excitation_waveform)[T.梯形波]                                        -2.547e+04   3.08e+04     -0.828      0.408   -8.58e+04    3.48e+04
# C(excitation_waveform)[T.正弦波]                                        -1.452e+05   2.89e+04     -5.026      0.000   -2.02e+05   -8.86e+04
# C(leixing)[T.材料2]:C(temperature)[T.50]                               -4.313e+04    4.2e+04     -1.026      0.305   -1.26e+05    3.93e+04
# C(leixing)[T.材料3]:C(temperature)[T.50]                               -6467.7179   4.12e+04     -0.157      0.875   -8.71e+04    7.42e+04
# C(leixing)[T.材料4]:C(temperature)[T.50]                                 2.09e+04   3.73e+04      0.560      0.575   -5.22e+04     9.4e+04
# C(leixing)[T.材料2]:C(temperature)[T.70]                               -4.037e+04   4.23e+04     -0.954      0.340   -1.23e+05    4.26e+04
# C(leixing)[T.材料3]:C(temperature)[T.70]                                -317.8075   4.13e+04     -0.008      0.994   -8.13e+04    8.07e+04
# C(leixing)[T.材料4]:C(temperature)[T.70]                                7.008e+04   3.76e+04      1.865      0.062   -3571.927    1.44e+05
# C(leixing)[T.材料2]:C(temperature)[T.90]                               -3.088e+04   4.23e+04     -0.731      0.465   -1.14e+05     5.2e+04
# C(leixing)[T.材料3]:C(temperature)[T.90]                               -2.197e+04   4.08e+04     -0.538      0.590   -1.02e+05     5.8e+04
# C(leixing)[T.材料4]:C(temperature)[T.90]                                 5.81e+04   3.78e+04      1.536      0.125    -1.6e+04    1.32e+05
# C(leixing)[T.材料2]:C(excitation_waveform)[T.梯形波]                      -3.483e+04   4.57e+04     -0.762      0.446   -1.24e+05    5.47e+04
# C(leixing)[T.材料3]:C(excitation_waveform)[T.梯形波]                       5.774e+04   4.34e+04      1.329      0.184   -2.74e+04    1.43e+05
# C(leixing)[T.材料4]:C(excitation_waveform)[T.梯形波]                       1.009e+05   5.76e+04      1.753      0.080   -1.19e+04    2.14e+05
# C(leixing)[T.材料2]:C(excitation_waveform)[T.正弦波]                      -1.591e+05   4.17e+04     -3.813      0.000   -2.41e+05   -7.73e+04
# C(leixing)[T.材料3]:C(excitation_waveform)[T.正弦波]                       -1.13e+05   4.18e+04     -2.704      0.007   -1.95e+05   -3.11e+04
# C(leixing)[T.材料4]:C(excitation_waveform)[T.正弦波]                       4.033e+04   4.18e+04      0.966      0.334   -4.15e+04    1.22e+05
# C(temperature)[T.50]:C(excitation_waveform)[T.梯形波]                   -1.181e+04   4.33e+04     -0.273      0.785   -9.67e+04    7.31e+04
# C(temperature)[T.70]:C(excitation_waveform)[T.梯形波]                   -2333.0760   4.34e+04     -0.054      0.957   -8.73e+04    8.27e+04
# C(temperature)[T.90]:C(excitation_waveform)[T.梯形波]                   -1.349e+04   4.35e+04     -0.310      0.756   -9.87e+04    7.17e+04
# C(temperature)[T.50]:C(excitation_waveform)[T.正弦波]                    1.221e+04   4.14e+04      0.295      0.768   -6.89e+04    9.33e+04
# C(temperature)[T.70]:C(excitation_waveform)[T.正弦波]                    3.653e+04   4.14e+04      0.883      0.377   -4.46e+04    1.18e+05
# C(temperature)[T.90]:C(excitation_waveform)[T.正弦波]                    2.651e+04   4.11e+04      0.645      0.519   -5.41e+04    1.07e+05
# C(leixing)[T.材料2]:C(temperature)[T.50]:C(excitation_waveform)[T.梯形波]  5.105e+04   6.41e+04      0.796      0.426   -7.46e+04    1.77e+05
# C(leixing)[T.材料3]:C(temperature)[T.50]:C(excitation_waveform)[T.梯形波] -3986.6518   6.16e+04     -0.065      0.948   -1.25e+05    1.17e+05
# C(leixing)[T.材料4]:C(temperature)[T.50]:C(excitation_waveform)[T.梯形波] -5.006e+04   7.55e+04     -0.663      0.507   -1.98e+05    9.79e+04
# C(leixing)[T.材料2]:C(temperature)[T.70]:C(excitation_waveform)[T.梯形波]  1.843e+04    6.4e+04      0.288      0.773   -1.07e+05    1.44e+05
# C(leixing)[T.材料3]:C(temperature)[T.70]:C(excitation_waveform)[T.梯形波] -1.173e+04   6.16e+04     -0.190      0.849   -1.32e+05    1.09e+05
# C(leixing)[T.材料4]:C(temperature)[T.70]:C(excitation_waveform)[T.梯形波] -9.686e+04   7.54e+04     -1.285      0.199   -2.45e+05    5.09e+04
# C(leixing)[T.材料2]:C(temperature)[T.90]:C(excitation_waveform)[T.梯形波]   2.37e+04   6.42e+04      0.369      0.712   -1.02e+05     1.5e+05
# C(leixing)[T.材料3]:C(temperature)[T.90]:C(excitation_waveform)[T.梯形波] -1.256e+04   6.13e+04     -0.205      0.838   -1.33e+05    1.08e+05
# C(leixing)[T.材料4]:C(temperature)[T.90]:C(excitation_waveform)[T.梯形波] -9.394e+04   7.41e+04     -1.267      0.205   -2.39e+05    5.13e+04
# C(leixing)[T.材料2]:C(temperature)[T.50]:C(excitation_waveform)[T.正弦波]  6.838e+04   6.05e+04      1.131      0.258   -5.01e+04    1.87e+05
# C(leixing)[T.材料3]:C(temperature)[T.50]:C(excitation_waveform)[T.正弦波]  1.247e+04   6.02e+04      0.207      0.836   -1.06e+05     1.3e+05
# C(leixing)[T.材料4]:C(temperature)[T.50]:C(excitation_waveform)[T.正弦波]  8634.8245   5.97e+04      0.145      0.885   -1.08e+05    1.26e+05
# C(leixing)[T.材料2]:C(temperature)[T.70]:C(excitation_waveform)[T.正弦波]  5.476e+04   6.03e+04      0.908      0.364   -6.34e+04    1.73e+05
# C(leixing)[T.材料3]:C(temperature)[T.70]:C(excitation_waveform)[T.正弦波] -8997.7303   6.11e+04     -0.147      0.883   -1.29e+05    1.11e+05
# C(leixing)[T.材料4]:C(temperature)[T.70]:C(excitation_waveform)[T.正弦波] -3.326e+04   5.99e+04     -0.555      0.579   -1.51e+05    8.43e+04
# C(leixing)[T.材料2]:C(temperature)[T.90]:C(excitation_waveform)[T.正弦波]  4.555e+04   6.06e+04      0.752      0.452   -7.32e+04    1.64e+05
# C(leixing)[T.材料3]:C(temperature)[T.90]:C(excitation_waveform)[T.正弦波]   4.11e+04   6.02e+04      0.683      0.495   -7.69e+04    1.59e+05
# C(leixing)[T.材料4]:C(temperature)[T.90]:C(excitation_waveform)[T.正弦波] -1.851e+04   6.01e+04     -0.308      0.758   -1.36e+05    9.92e+04
# ==============================================================================
# Omnibus:                     8695.898   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           136966.989
# Skew:                           3.253   Prob(JB):                         0.00
# Kurtosis:                      17.926   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept                                                               2.326331e-49
# C(leixing)[T.材料2]                                                       4.476440e-06
# C(leixing)[T.材料3]                                                       1.539220e-04
# C(leixing)[T.材料4]                                                       8.773499e-07
# C(temperature)[T.50]                                                    1.022726e-01
# C(temperature)[T.70]                                                    2.624052e-03
# C(temperature)[T.90]                                                    4.473636e-03
# C(excitation_waveform)[T.梯形波]                                           4.078224e-01
# C(excitation_waveform)[T.正弦波]                                           5.082085e-07
# C(leixing)[T.材料2]:C(temperature)[T.50]                                  3.048938e-01
# C(leixing)[T.材料3]:C(temperature)[T.50]                                  8.751176e-01
# C(leixing)[T.材料4]:C(temperature)[T.50]                                  5.751884e-01
# C(leixing)[T.材料2]:C(temperature)[T.70]                                  3.399694e-01
# C(leixing)[T.材料3]:C(temperature)[T.70]                                  9.938624e-01
# C(leixing)[T.材料4]:C(temperature)[T.70]                                  6.219279e-02
# C(leixing)[T.材料2]:C(temperature)[T.90]                                  4.650879e-01
# C(leixing)[T.材料3]:C(temperature)[T.90]                                  5.904095e-01
# C(leixing)[T.材料4]:C(temperature)[T.90]                                  1.245907e-01
# C(leixing)[T.材料2]:C(excitation_waveform)[T.梯形波]                         4.458901e-01
# C(leixing)[T.材料3]:C(excitation_waveform)[T.梯形波]                         1.837561e-01
# C(leixing)[T.材料4]:C(excitation_waveform)[T.梯形波]                         7.957464e-02
# C(leixing)[T.材料2]:C(excitation_waveform)[T.正弦波]                         1.382014e-04
# C(leixing)[T.材料3]:C(excitation_waveform)[T.正弦波]                         6.859508e-03
# C(leixing)[T.材料4]:C(excitation_waveform)[T.正弦波]                         3.343120e-01
# C(temperature)[T.50]:C(excitation_waveform)[T.梯形波]                      7.850632e-01
# C(temperature)[T.70]:C(excitation_waveform)[T.梯形波]                      9.571016e-01
# C(temperature)[T.90]:C(excitation_waveform)[T.梯形波]                      7.562849e-01
# C(temperature)[T.50]:C(excitation_waveform)[T.正弦波]                      7.678504e-01
# C(temperature)[T.70]:C(excitation_waveform)[T.正弦波]                      3.771669e-01
# C(temperature)[T.90]:C(excitation_waveform)[T.正弦波]                      5.189878e-01
# C(leixing)[T.材料2]:C(temperature)[T.50]:C(excitation_waveform)[T.梯形波]    4.259986e-01
# C(leixing)[T.材料3]:C(temperature)[T.50]:C(excitation_waveform)[T.梯形波]    9.483697e-01
# C(leixing)[T.材料4]:C(temperature)[T.50]:C(excitation_waveform)[T.梯形波]    5.073157e-01
# C(leixing)[T.材料2]:C(temperature)[T.70]:C(excitation_waveform)[T.梯形波]    7.734601e-01
# C(leixing)[T.材料3]:C(temperature)[T.70]:C(excitation_waveform)[T.梯形波]    8.489572e-01
# C(leixing)[T.材料4]:C(temperature)[T.70]:C(excitation_waveform)[T.梯形波]    1.988780e-01
# C(leixing)[T.材料2]:C(temperature)[T.90]:C(excitation_waveform)[T.梯形波]    7.120711e-01
# C(leixing)[T.材料3]:C(temperature)[T.90]:C(excitation_waveform)[T.梯形波]    8.377534e-01
# C(leixing)[T.材料4]:C(temperature)[T.90]:C(excitation_waveform)[T.梯形波]    2.050374e-01
# C(leixing)[T.材料2]:C(temperature)[T.50]:C(excitation_waveform)[T.正弦波]    2.581173e-01
# C(leixing)[T.材料3]:C(temperature)[T.50]:C(excitation_waveform)[T.正弦波]    8.358929e-01
# C(leixing)[T.材料4]:C(temperature)[T.50]:C(excitation_waveform)[T.正弦波]    8.850179e-01
# C(leixing)[T.材料2]:C(temperature)[T.70]:C(excitation_waveform)[T.正弦波]    3.637767e-01
# C(leixing)[T.材料3]:C(temperature)[T.70]:C(excitation_waveform)[T.正弦波]    8.828481e-01
# C(leixing)[T.材料4]:C(temperature)[T.70]:C(excitation_waveform)[T.正弦波]    5.790791e-01
# C(leixing)[T.材料2]:C(temperature)[T.90]:C(excitation_waveform)[T.正弦波]    4.521364e-01
# C(leixing)[T.材料3]:C(temperature)[T.90]:C(excitation_waveform)[T.正弦波]    4.947614e-01
# C(leixing)[T.材料4]:C(temperature)[T.90]:C(excitation_waveform)[T.正弦波]    7.579920e-01
# dtype: float64

# %%
import pandas as pd
import numpy as np
from scipy.stats import friedmanchisquare
# 读取数据
data = pd.read_excel('附件一（训练集）.xlsx')
# 假设数据已经加载为 DataFrame，且 leixing、temperature、core_loss、excitation_waveform 已正确存储在各列中
# 示例数据加载
# data = pd.read_csv('your_data_file.csv') # 这里是你的数据文件路径
# 假设data已经加载为DataFrame
leixing= data.iloc[:, 0].values  # 材料类型
temperature = data.iloc[:, 1].values  # 温度
core_loss = data.iloc[:, 3].values  # 核损耗
excitation_waveform= data.iloc[:, 4].values  # 励磁波形

# 创建一个新的 DataFrame 用于分析
df = pd.DataFrame({
    'leixing': leixing,
    'temperature': temperature,
    'core_loss': core_loss,
    'excitation_waveform': excitation_waveform
})

# 查看前5行数据
print("数据预览:")
print(df.head())

# 定义函数，执行弗里德曼检验并输出结果
def friedman_test_for_single_variable(data, var):
    # 按分类变量分组后提取核损耗值
    groups = [group['core_loss'].values for name, group in data.groupby(var)]
    # 执行弗里德曼检验
    if len(groups) > 1:  # 确保至少有两个组
        stat, p = friedmanchisquare(*groups)
        print(f"Friedman test for {var}: chi-square statistic = {stat}, p-value = {p}")
        return stat, p
    else:
        print(f"变量 {var} 的分类值不足以执行弗里德曼检验。")
        return None, None

# 对单独的材料类型、温度、励磁波形执行弗里德曼检验
#print("\n单个变量弗里德曼检验结果:")
#friedman_test_for_single_variable(df, 'leixing')
#friedman_test_for_single_variable(df, 'temperature')
#friedman_test_for_single_variable(df, 'excitation_waveform')
# Out:
# 数据预览:
#   leixing  temperature    core_loss excitation_waveform
# 0     材料1           25  1997.955250                 正弦波
# 1     材料1           25  2427.749830                 正弦波
# 2     材料1           25  3332.725760                 正弦波
# 3     材料1           25  4502.908007                 正弦波
# 4     材料1           25  6063.023248                 正弦波
#
# 单个变量弗里德曼检验结果:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 42
#      40 # 对单独的材料类型、温度、励磁波形执行弗里德曼检验
#      41 print("\n单个变量弗里德曼检验结果:")
# ---> 42 friedman_test_for_single_variable(df, 'leixing')
#      43 friedman_test_for_single_variable(df, 'temperature')
#      44 friedman_test_for_single_variable(df, 'excitation_waveform')
#
# Cell In[30], line 33, in friedman_test_for_single_variable(data, var)
#      31 # 执行弗里德曼检验
#      32 if len(groups) > 1:  # 确保至少有两个组
# ---> 33     stat, p = friedmanchisquare(*groups)
#      34     print(f"Friedman test for {var}: chi-square statistic = {stat}, p-value = {p}")
#      35     return stat, p
#
# File d:\Anaconda\envs\pytorch\lib\site-packages\scipy\stats\_stats_py.py:8679, in friedmanchisquare(*samples)
#    8677 for i in range(1, k):
#    8678     if len(samples[i]) != n:
# -> 8679         raise ValueError('Unequal N in friedmanchisquare.  Aborting.')
#    8681 # Rank data
#    8682 data = np.vstack(samples).T
#
# ValueError: Unequal N in friedmanchisquare.  Aborting.

# %%
import pandas as pd
import numpy as np
from scipy.stats import friedmanchisquare
# 读取数据
data = pd.read_excel('附件一（训练集）.xlsx')
# 假设数据已经加载为 DataFrame，且 leixing、temperature、core_loss、excitation_waveform 已正确存储在各列中
# 示例数据加载
# data = pd.read_csv('your_data_file.csv') # 这里是你的数据文件路径
# 假设data已经加载为DataFrame
leixing= data.iloc[:, 0].values  # 材料类型
temperature = data.iloc[:, 1].values  # 温度
core_loss = data.iloc[:, 3].values  # 核损耗
excitation_waveform= data.iloc[:, 4].values  # 励磁波形

# 创建一个新的 DataFrame 用于分析
df = pd.DataFrame({
    'leixing': leixing,
    'temperature': temperature,
    'core_loss': core_loss,
    'excitation_waveform': excitation_waveform
})

# 查看前5行数据
print("数据预览:")
print(df.head())
# Out:
# 数据预览:
#   leixing  temperature    core_loss excitation_waveform
# 0     材料1           25  1997.955250                 正弦波
# 1     材料1           25  2427.749830                 正弦波
# 2     材料1           25  3332.725760                 正弦波
# 3     材料1           25  4502.908007                 正弦波
# 4     材料1           25  6063.023248                 正弦波

# %%
import pandas as pd
import numpy as np
from scipy.stats import friedmanchisquare

# 定义函数，执行弗里德曼检验并输出结果
def friedman_test_for_single_variable(data, var):
    # 按分类变量分组后提取核损耗值
    groups = [group['core_loss'].values for name, group in data.groupby(var)]
    
    # 检查所有组是否有相同数量的样本
    group_lengths = [len(group) for group in groups]
    if len(set(group_lengths)) != 1:
        print(f"分类变量 {var} 的分组样本数量不一致，无法执行弗里德曼检验。")
        print(f"每组的样本数量分别为: {group_lengths}")
        return None, None

    # 执行弗里德曼检验
    if len(groups) > 1:  # 确保至少有两个组
        stat, p = friedmanchisquare(*groups)
        print(f"Friedman test for {var}: chi-square statistic = {stat}, p-value = {p}")
        return stat, p
    else:
        print(f"变量 {var} 的分类值不足以执行弗里德曼检验。")
        return None, None

# 对单独的材料类型、温度、励磁波形执行弗里德曼检验
print("\n单个变量弗里德曼检验结果:")
friedman_test_for_single_variable(df, 'leixing')
friedman_test_for_single_variable(df, 'temperature')
friedman_test_for_single_variable(df, 'excitation_waveform')

# 创建交互变量时，确保变量是字符串类型
df['leixing'] = df['leixing'].astype(str)
df['temperature'] = df['temperature'].astype(str)
df['excitation_waveform'] = df['excitation_waveform'].astype(str)

# 创建交互变量
df['leixing_temperature'] = df['leixing'] + "_" + df['temperature']
df['temperature_excitation_waveform'] = df['temperature'] + "_" + df['excitation_waveform']
df['leixing_excitation_waveform'] = df['leixing'] + "_" + df['excitation_waveform']

# 对交互变量执行弗里德曼检验
print("\n交互变量弗里德曼检验结果:")
friedman_test_for_single_variable(df, 'leixing_temperature')
friedman_test_for_single_variable(df, 'temperature_excitation_waveform')
friedman_test_for_single_variable(df, 'leixing_excitation_waveform')
# Out:
# 单个变量弗里德曼检验结果:
# 分类变量 leixing 的分组样本数量不一致，无法执行弗里德曼检验。
# 每组的样本数量分别为: [3400, 3000, 3200, 2800]
# 分类变量 temperature 的分组样本数量不一致，无法执行弗里德曼检验。
# 每组的样本数量分别为: [3244, 3070, 3030, 3056]
# 分类变量 excitation_waveform 的分组样本数量不一致，无法执行弗里德曼检验。
# 每组的样本数量分别为: [4948, 3398, 4054]
#
# 交互变量弗里德曼检验结果:
# 分类变量 leixing_temperature 的分组样本数量不一致，无法执行弗里德曼检验。
# 每组的样本数量分别为: [861, 845, 843, 851, 813, 727, 746, 714, 850, 801, 754, 795, 720, 697, 687, 696]
# 分类变量 temperature_excitation_waveform 的分组样本数量不一致，无法执行弗里德曼检验。
# 每组的样本数量分别为: [1338, 776, 1130, 1215, 856, 999, 1195, 871, 964, 1200, 895, 961]
# 分类变量 leixing_excitation_waveform 的分组样本数量不一致，无法执行弗里德曼检验。
# 每组的样本数量分别为: [1412, 921, 1067, 1003, 900, 1097, 1078, 1112, 1010, 1455, 465, 880]
# (None, None)
